# %% [markdown]
# # Praktikum Scrapy

# %% [markdown]
# ### import library

# %%
import scrapy
import os
os.chdir('scrapy_imdb/')

# %% [markdown]
# ### Start Project

# %%
# !scrapy startproject scraping_movies
# Out:
# New Scrapy project 'scraping_movies', using template directory 'C:\Python311\Lib\site-packages\scrapy\templates\project', created in:
#     C:\Users\Hendra Kusuma\OneDrive - UGM 365\Documents\Semester 6\1.Teknologi Perekayasaan Data\Git\meet4\scrapy_imdb\scraping_movies
#
# You can start your first spider with:
#     cd scraping_movies
#     scrapy genspider example example.com

# %%
os.chdir('scraping_movies/scraping_movies/spiders/')

# %%
# !scrapy genspider movies https://www.imdb.com/chart/top/
# Out:
# Created spider 'movies' using template 'basic' in module:
#   scraping_movies.spiders.movies

# %% [markdown]
# ### Crawling

# %%
# !scrapy crawl movies
# !scrapy crawl movies -o top_movies.csv
# Out:
# 2023-02-27 21:45:48 [scrapy.utils.log] INFO: Scrapy 2.8.0 started (bot: scraping_movies)
# 2023-02-27 21:45:48 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.12, cssselect 1.2.0, parsel 1.7.0, w3lib 2.1.1, Twisted 22.10.0, Python 3.11.1 (tags/v3.11.1:a7a450f, Dec  6 2022, 19:58:39) [MSC v.1934 64 bit (AMD64)], pyOpenSSL 23.0.0 (OpenSSL 3.0.8 7 Feb 2023), cryptography 39.0.1, Platform Windows-10-10.0.22621-SP0
# 2023-02-27 21:45:48 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'scraping_movies',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'scraping_movies.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['scraping_movies.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2023-02-27 21:45:48 [asyncio] DEBUG: Using selector: SelectSelector
# ...

# %%
# Out:
# 2023-02-27 11:22:02 [scrapy.utils.log] INFO: Scrapy 2.8.0 started (bot: scraping_movies)
# 2023-02-27 11:22:02 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.12, cssselect 1.2.0, parsel 1.7.0, w3lib 2.1.1, Twisted 22.10.0, Python 3.11.1 (tags/v3.11.1:a7a450f, Dec  6 2022, 19:58:39) [MSC v.1934 64 bit (AMD64)], pyOpenSSL 23.0.0 (OpenSSL 3.0.8 7 Feb 2023), cryptography 39.0.1, Platform Windows-10-10.0.22621-SP0
# 2023-02-27 11:22:02 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'scraping_movies',
#  'DOWNLOAD_DELAY': 3,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'scraping_movies.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'SPIDER_MODULES': ['scraping_movies.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2023-02-27 11:22:02 [asyncio] DEBUG: Using selector: SelectSelector
# ...
